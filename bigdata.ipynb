# %% [markdown]
# <a href="https://colab.research.google.com/github/bear2u/datascience-study2/blob/master/bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
laptop_df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/laptops.csv')
laptop_df
# Out:
#          brand                          model  ram hd_type  hd_size  \
# 0         Dell               Inspiron 15-3567    4     hdd     1024
# 1        Apple                    MacBook Air    8     ssd      128
# 2        Apple                    MacBook Air    8     ssd      256
# 3        Apple                    MacBook Pro    8     ssd      128
# 4        Apple                    MacBook Pro    8     ssd      256
# 5        Apple         MacBook Pro (TouchBar)   16     ssd      512
# 6        Apple         MacBook Pro (TouchBar)   16     ssd      512
# 7        Apple                       MacBook     8     ssd      256
# 8         Dell                    Vostro 3468    4     hdd     1024
# 9         Dell             Inspiron 15.6 3552    4     hdd      500
# 10        Dell                   Vostro 3468     4     hdd     1024
# 11        Dell               Inspiron 14 3442    4     hdd      500
# 12        Dell               Inspiron 15 3567    4     hdd     1024
# ...

# %% [markdown]
# 데이터 프레임에서 상위 출력
# `head()`
#
# 데이터 프레임에서 하위 출력
# `tail()`
#
# shap : 줄 / 컬럼

# %%
laptop_df.sort_values('price', inplace=True)
laptop_df
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# 143       Acer                Aspire ES 15    4     hdd     1024         15.6
# 158       Asus               X540YA-XO290D    4     hdd     1024         15.6
# 14        Dell            Inspiron 15 3565    4     hdd      500         15.0
# 9         Dell          Inspiron 15.6 3552    4     hdd      500         15.0
# 119         HP              245 G4,P1b38PA    4     ssd     1024         15.6
# 159       Asus                     P2420SA    4     hdd      500         14.0
# ...

# %%
# 여행을 좋아하는 익중이는 여행지를 알아보고 있습니다. 주어진 데이터에는 총 몇 개의 도시와 몇 개의 나라가 있는지 알아맞혀 보세요.

df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/world_cities.csv')
# df
print(df['City / Urban area'].value_counts().shape)
print(df['Country'].value_counts().shape)
# Out:
# (249,)
# (61,)

# %%
# 사람 만나기를 좋아하는 익중이는 가장 사람이 붐비는 도시로 여행을 가기로 마음 먹었습니다. 
# 주어진 데이터에서, 인구 밀도(명/sqKm) 가 10000 이 넘는 도시는 총 몇 개인지 알아보세요.

df.loc[df['Population'] / df['Land area (in sqKm)'] > 10000,'City / Urban area'].value_counts().shape
# Out:
# (19,)

# %%
# 3. 이번에는 인구 밀도가 가장 높은 도시를 찾아봅시다. 

df['count'] = df['Population'] / df['Land area (in sqKm)']
df.sort_values(by='count', ascending=False)
# Out:
#            City / Urban area      Country  Population  Land area (in sqKm)  \
# 75                    Mumbai        India    14350000                  484
# 74                   Kolkata        India    12700000                  531
# 101                  Karachi     Pakistan     9800000                  518
# 99                     Lagos      Nigeria    13400000                  738
# 34                  Shenzhen        China     8000000                  466
# 123            Seoul/Incheon  South Korea    17500000                 1049
# 129                   Taipei       Taiwan     5700000                  376
# 76                   Chennai        India     5950000                  414
# 38                    Bogota     Colombia     7000000                  518
# 33                  Shanghai        China    10000000                  746
# 102                     Lima         Peru     7000000                  596
# ...

# %%
# 익중이는 누나에게 여행지를 추천 받으려고 합니다. 그런데 나라 이름이 기억나지 않고, 이 데이터에 4개의 도시가 나왔다는 것만 기억이 난다고 하네요. 이 나라는 무엇일까요?
df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/world_cities.csv')
countries = df['Country'].value_counts()
countries[countries == 4]
# Out:
# Italy    4
# Name: Country, dtype: int64

# %%
# %matplotlib inline

df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/broadcast.csv', index_col=0)
df.plot()

# %%
df.plot(y='KBS')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/gdp.csv', index_col=0)
df

countries = ["Korea_Rep", "United_States", "United_Kingdom", "Germany", "China", "Japan"]
df[countries].plot()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/slicon_vally_summary.csv')
df
# Out:
#      job_category             race_ethnicity  gender   count  percentage
# 0     All workers                      White    Male  268883   41.257252
# 1     All workers                      White  Female  105560   16.197065
# 2     All workers  Black_or_African American    Male   17508    2.686417
# 3     All workers  Black_or_African American  Female   11479    1.761331
# 4     All workers                      Asian    Male  125347   19.233171
# 5     All workers                      Asian  Female   58049    8.907005
# 6     All workers         Hispanic_or_Latino    Male   32201    4.940903
# 7     All workers         Hispanic_or_Latino  Female   15512    2.380152
# 8     All workers                        All    Male  454813   69.786244
# 9     All workers                        All  Female  196910   30.213756
# 10    All workers                     Totals    Both  651723  100.000000
# 11     Executives                      White    Male    7282   58.678485
# ...

# %%
filters = df[(df['job_category'] == 'Managers') & (df['gender'] == 'Male')]
filters.plot(kind='bar', x='race_ethnicity', y='count')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bear2u/datascience-study2/master/csv/silcon_vally_detail.csv')
df
# Out:
#       company  year                race  gender            job_category  count
# 0     23andMe  2016  Hispanic_or_Latino    male              Executives      0
# 1     23andMe  2016  Hispanic_or_Latino    male                Managers      1
# 2     23andMe  2016  Hispanic_or_Latino    male           Professionals      7
# 3     23andMe  2016  Hispanic_or_Latino    male             Technicians      0
# 4     23andMe  2016  Hispanic_or_Latino    male           Sales workers      0
# 5     23andMe  2016  Hispanic_or_Latino    male  Administrative support      0
# 6     23andMe  2016  Hispanic_or_Latino    male           Craft workers      0
# 7     23andMe  2016  Hispanic_or_Latino    male              operatives      0
# 8     23andMe  2016  Hispanic_or_Latino    male    laborers and helpers      0
# 9     23andMe  2016  Hispanic_or_Latino    male         Service workers      0
# 10    23andMe  2016  Hispanic_or_Latino    male                  Totals      8
# ...

# %%
# 이번에는 어도비 (Adobe)의 직원 분포를 한번 살펴봅시다.

# 어도비 전체 직원들의 직군 분포를 파이 그래프로 그려보세요.

# (인원이 0인 직군은 그래프에 표시되지 않아야 합니다.)

adobe_df = df[(df['company'] =='Adobe') & (df['count'] != 0) & (df['job_category'] != 'Totals')]           
# adobe_serise = adobe_df['job_category'].value_counts()
# adobe_serise
adobe_df
# adobe_df.plot(kind='pie', y='count')
# Out:
#     company  year                                 race  gender  \
# 165   Adobe  2016                   Hispanic_or_Latino    male
# 166   Adobe  2016                   Hispanic_or_Latino    male
# 167   Adobe  2016                   Hispanic_or_Latino    male
# 169   Adobe  2016                   Hispanic_or_Latino    male
# 170   Adobe  2016                   Hispanic_or_Latino    male
# 176   Adobe  2016                   Hispanic_or_Latino    male
# 178   Adobe  2016                   Hispanic_or_Latino  female
# 179   Adobe  2016                   Hispanic_or_Latino  female
# 181   Adobe  2016                   Hispanic_or_Latino  female
# 182   Adobe  2016                   Hispanic_or_Latino  female
# 188   Adobe  2016                   Hispanic_or_Latino  female
# 189   Adobe  2016                                White    male
# 190   Adobe  2016                                White    male
# 191   Adobe  2016                                White    male
# ...
